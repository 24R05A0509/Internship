# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('C:/Users/student/Desktop/gender_submission.csv')
print(dataset)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
df=pd.DataFrame(dataset)

# %%
X=list(df.iloc[:,0])
Y=list(df.iloc[:,1])

# %%
plt.bar(X,Y,color='g')
plt.title('gendersubmission')
plt.xlabel("PassengerId")
plt.ylabel("Survived")
plt.show()
